# %%
pip install opencv-python

# %%
pip install -U nltk
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 8.5 MB/s
# ...
#      |████████████████████████████████| 749 kB 47.4 MB/s
# ...
#   Attempting uninstall: regex
#     Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# ...

# %%
pip install spacy==2.3.5
# Out:
# ...
#      |████████████████████████████████| 10.4 MB 8.1 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 67.9 MB/s
# ...
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ...

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# Out:
# ...
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
# ...

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp('"Lets\'s go to N.Y.!"')
for token in doc:
  print(token.text)
# Out:
# "
# Lets
# 's
# go
# to
# N.Y.
# !
# "

# %%
pip install datapane
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 8.6 MB/s
# ...
#      |████████████████████████████████| 45 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 73.6 MB/s
# ...
#      |████████████████████████████████| 97 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 46 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 71 kB 146 kB/s
# ...
#      |████████████████████████████████| 193 kB 57.5 MB/s
# ...
#      |████████████████████████████████| 10.9 MB 55.9 MB/s
# ...
#      |████████████████████████████████| 46 kB 3.6 MB/s
# ...
#   Created wheel for face: filename=face-20.1.1-py3-none-any.whl size=51091 sha256=167a82fed0d70a24eabc48c51babcb4c4c3e2de7b33c571797c8ae64ac5b0838
#   Stored in directory: /root/.cache/pip/wheels/67/03/c2/76d2e1e694852ce409ac2938b9f461bc0fdf3789901e7bb1f0
# ...
#   Created wheel for micawber: filename=micawber-0.5.4-py3-none-any.whl size=22373 sha256=cd00d47d892017417a06f23f222c5d7856cf4cb6902c3ded2ca1a168d20e9f69
# ...

# %%
pip install snowflake-connector-python
# Out:
# ...
#      |████████████████████████████████| 16.4 MB 9.5 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 65.7 MB/s
# ...
#      |████████████████████████████████| 104 kB 72.7 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 42.7 MB/s
# ...
#      |████████████████████████████████| 192 kB 47.8 MB/s
# ...
#      |████████████████████████████████| 55 kB 2.8 MB/s
# ...

# %%
import datapane as dp
import snowflake.connector
from internal_lib import forecast

conn = snowflake.connector.connect(...)
users = conn.execute_query('get_users.sql').fetchall()
f_data, f_plot = forecast.predict(df)

sales_v_profit = alt.Chart(users).encode(x='sales', y='profit', color='category')

dp.Report(by_name='forecast').update_assets(
    dp.Plot(sales_v_profit, name='sale_v_profit'),
    dp.DataTable(f_data, name='forecast_data'),
    dp.Plot(f_plot, name='forecast_plot')
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-19c249d1820f> in <module>()
#       1 import datapane as dp
#       2 import snowflake.connector
# ----> 3 from internal_lib import forecast
#       4
#       5 conn = snowflake.connector.connect(...)
#
# ModuleNotFoundError: No module named 'internal_lib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Visualizing named entity**
# spaCy has a built-in visualizer to visualize the named entity. For doing so, we have to import displacy module from spaCy library.

# %%
from spacy import displacy
doc=nlp(u'Over last few years USA generates $6 million revenue')
displacy.render(doc,style='ent',jupyter=True)

# %%
document=nlp(u'India is a beautiful country')
displacy.render(document,style='dep',jupyter=True,options={'distance':110})

# %%
import nltk
from nltk.stem.porter import *
p_stemmer=PorterStemmer()
words= ['run','runner','running','ran','runs','easily','fairly']
for word in words:
  print(word+'--> '+p_stemmer.stem(word))

# %%
from nltk.stem.snowball import SnowballStemmer

s_stemmer=SnowballStemmer(language='english')
words=['run','runner','running','ran','runs','easily','fairly']
for word in words:
  print(word+' ---> '+s_stemmer.stem(word))

# %%
doc=nlp(u'He is a runner running in a competition because he loves to run since he ran today ')
for token in doc:
  print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}}{token.lemma_}')

# %%
nlp_1=spacy.load('en_core_web_sm')
print(nlp_1.Defaults.stop_words)

# %%
nlp_1.vocab['myself'].is_stop

# %%
nlp_1.vocab['hello'].is_stop

# %%
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
pattern_1= [{'Lower':'solarpower'}]
pattern_2= [{'Lower':'solar'},{'Lower':'power'}]
pattern_3= [{'Lower':'solar'},{'is_punct':True},{'lower':'power'}]

matcher.add('solarpower',None,pattern_1,pattern_2,pattern_3)

# %%
document=nlp(u'The Solar Power industry continues to grow as demand\
for solarpower increases. Solar-power cars are gaining popularity.')

found_matches=matcher(document)
print(found_matches)

# %%
for match_id, start, end in found_matches:
  string_id=nlp.vocab.strings[match_id]
  span = document[start:end]
  print(match_id,string_id,start,end,span.text)

# %%
import spacy
from spacy.matcher import PhraseMatcher

nlp=spacy.load("en_core_web_sm")
matcher=PhraseMatcher(nlp.vocab)
terms = ["Barack Obama","Angela Merkel", "Washington, D.C."]
patterns=[nlp.make_doc(text) for text in terms]
matcher.add("patterns_1",patterns)
doc= nlp("German Chancellor Angela Merkel and US President Barack Obama "
"converse in the oval office inside the white House in Washington, D.C.")
matches = matcher(doc)
for match_id, start,end in matches:
  span=doc[start:end]
  print(span.text)

# %%
import datapane as dp
import snowflake.connector
from internal_lib import forecast

conn = snowflake.connector.connect(...)
users = conn.execute_query('get_users.sql').fetchall()
f_data, f_plot = forecast.predict(df)

sales_v_profit = alt.Chart(users).encode(x='sales', y='profit', color='category')

dp.Report(by_name='forecast').update_assets(
    dp.Plot(sales_v_profit, name='sale_v_profit')
    dp.DataTable(f_data, name='forecast_data'),
    dp.Plot(f_plot, name='forecast_plot')
)
